# %%
from drptools.data import DRPImages
# Out:
# /afs/in2p3.fr/home/n/nchotard/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
path = "/sps/lsst/dataproducts/desc/DC2/Run1.1-test2/w_2018_14/work/0/output/"

# %%
images = DRPImages(path)
# Out:
# /sps/lsst/software/lsst_distrib/w_2018_15/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
images.display("eimage", images.dataIds['raw'][0])

# %%
eimage = images.butler.get('eimage', dataId=images.dataIds['raw'][0])

# %%
# %matplotlib notebook
import matplotlib
import lsst.afw.display as afwDisplay
display = afwDisplay.getDisplay(1, backend='matplotlib')
display.mtv(eimage)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from drptools import plots

# %%
f = images.get_file('eimage', images.dataIds['raw'][0])[0]
f

# %%
plots.js9(f)

# %%
js9path = "/pbs/throng/lsst/users/nchotard/drptools/drptools/static/js9-2.0.2"
js9path = "https://js9.si.edu/js9"
from IPython.core.display import HTML

# %%
HTML(
"""
<head>
<link type='text/css' rel='stylesheet' href='JS9PATH/js9support.css'>
<link type='text/css' rel='stylesheet' href='JS9PATH/js9.css'>
<script type='text/javascript' src='JS9PATH/js9prefs.js'></script>
<script type='text/javascript' src='JS9PATH/js9support.min.js'></script>
<script type='text/javascript' src='JS9PATH/js9.js'></script>
<script type='text/javascript' src='JS9PATH/js9plugins.js'></script>
</head>
<body>
<div class='JS9Menubar' data-width='600px'></div>
<div class='JS9Toolbar' data-width='600px'></div>
<div class='JS9' data-width='600px' data-height='600px'></div>
<div style='margin-top: 2px;' data-width='600px'>
<div class='JS9Colorbar' data-width='600px'></div>
<script type='text/javascript' src='JS9.Load(IMAGETOLOAD)'></script>
</div>
</body>
""".replace('IMAGETOLOAD', "/home/chotard/S11.fits").replace('JS9PATH', js9path))
